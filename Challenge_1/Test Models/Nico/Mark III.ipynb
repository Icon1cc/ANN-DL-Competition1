# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from os import listdir, environ
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
print(tf.version)
print(tf.config.list_physical_devices('GPU'))
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\nicol\\anaconda3\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# For reproducible results
seed = 42
environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ### Data

# %%
# Constants
val_size = 0.2
data_path = 'public_data.npz'

# %%
# Read data
plants = np.load(data_path, allow_pickle=True)
X = plants['data']
y = plants['labels']

# Normalize image pixel values to a float range [0, 1]
X = (X / 255).astype(np.float32)

# Convert labels to categorical format using one-hot encoding
label_encoding = {'healthy': 0, 'unhealthy': 1}
y = np.array([label_encoding[label] for label in y])
y = y.reshape(-1,1)

# Split into train and validation (hidden test set on codalab)
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=val_size, stratify=y)

print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (4160, 96, 96, 3) (1040, 96, 96, 3) (4160, 1) (1040, 1)

# %% [markdown]
# ### ML

# %%
# Model parameters 
input_shape = X.shape[1:] 
output_shape = 1 
batch_size = 128      
epochs = 200
dout = 0.2

# %%
## Model based on LeNet-5 architecture
# > Expanded receptive field (extra conv. and maxpooling at beginning of FEN)
# > Added dropout layers
# > using ReLU activations
model = tfk.models.Sequential([
    tfkl.Input(shape=input_shape, name='input'),
    tfkl.Conv2D(filters=6, kernel_size=(7,7), padding='same', activation='relu', name='conv1'),   
    tfkl.MaxPooling2D(pool_size=(3,3), name='mp1'),                                              
    tfkl.Conv2D(filters=6, kernel_size=(5,5), padding='valid', activation='relu', name='conv2'),  
    tfkl.MaxPooling2D(pool_size=(2,2), name='mp2'),                                               
    tfkl.Conv2D(filters=16, kernel_size=(5,5), padding='valid', activation='relu', name='conv3'),
    tfkl.MaxPooling2D(pool_size =(2,2), name='mp3'),                                              
    tfkl.Flatten(name='flatten'),
    tfkl.Dense(units=120, activation='relu', name='dense1'),
    tf.keras.layers.Dropout(rate=dout),
    tfkl.Dense(units=84, activation='relu', name='dense2'),
    tf.keras.layers.Dropout(rate=dout),
    tfkl.Dense(units=output_shape, activation='sigmoid', name='Output')
])

# Compile the model
model.compile(loss=tfk.losses.BinaryCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['binary_accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 96, 96, 6)         888
#
#  mp1 (MaxPooling2D)          (None, 32, 32, 6)         0
#
#  conv2 (Conv2D)              (None, 28, 28, 6)         906
#
#  mp2 (MaxPooling2D)          (None, 14, 14, 6)         0
#
#  conv3 (Conv2D)              (None, 10, 10, 16)        2416
#
#  mp3 (MaxPooling2D)          (None, 5, 5, 16)          0
#
#  flatten (Flatten)           (None, 400)               0
#
#  dense1 (Dense)              (None, 120)               48120
#
#  dropout (Dropout)           (None, 120)               0
#
#  dense2 (Dense)              (None, 84)                10164
#
#  dropout_1 (Dropout)         (None, 84)                0
#
#  Output (Dense)              (None, 1)                 85
#
# =================================================================
# Total params: 62,579
# Trainable params: 62,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tfk.callbacks.EarlyStopping(monitor='val_binary_accuracy', patience=20, mode='max', restore_best_weights=True)

# Train the model and save its history
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping]
).history

# Save the trained model
model.save('mark_III.h5')
# Out:
# Epoch 1/200
# 33/33 [==============================] - 3s 20ms/step - loss: 0.6679 - binary_accuracy: 0.6041 - val_loss: 0.6542 - val_binary_accuracy: 0.6154
# Epoch 2/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.6526 - binary_accuracy: 0.6151 - val_loss: 0.6428 - val_binary_accuracy: 0.6154
# Epoch 3/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.6386 - binary_accuracy: 0.6238 - val_loss: 0.6300 - val_binary_accuracy: 0.6385
# Epoch 4/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.6192 - binary_accuracy: 0.6668 - val_loss: 0.6300 - val_binary_accuracy: 0.6260
# Epoch 5/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5975 - binary_accuracy: 0.6901 - val_loss: 0.5990 - val_binary_accuracy: 0.6933
# Epoch 6/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5809 - binary_accuracy: 0.7010 - val_loss: 0.6168 - val_binary_accuracy: 0.6567
# Epoch 7/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5839 - binary_accuracy: 0.6981 - val_loss: 0.5843 - val_binary_accuracy: 0.6971
# Epoch 8/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5697 - binary_accuracy: 0.7063 - val_loss: 0.5726 - val_binary_accuracy: 0.7019
# Epoch 9/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5603 - binary_accuracy: 0.7144 - val_loss: 0.5747 - val_binary_accuracy: 0.7019
# Epoch 10/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5679 - binary_accuracy: 0.7060 - val_loss: 0.5739 - val_binary_accuracy: 0.6827
# Epoch 11/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5536 - binary_accuracy: 0.7212 - val_loss: 0.5943 - val_binary_accuracy: 0.6721
# Epoch 12/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5415 - binary_accuracy: 0.7207 - val_loss: 0.5729 - val_binary_accuracy: 0.6923
# Epoch 13/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5325 - binary_accuracy: 0.7281 - val_loss: 0.5720 - val_binary_accuracy: 0.6885
# Epoch 14/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5269 - binary_accuracy: 0.7389 - val_loss: 0.5511 - val_binary_accuracy: 0.7144
# Epoch 15/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5159 - binary_accuracy: 0.7421 - val_loss: 0.5527 - val_binary_accuracy: 0.7115
# Epoch 16/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5041 - binary_accuracy: 0.7601 - val_loss: 0.5592 - val_binary_accuracy: 0.7106
# Epoch 17/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5061 - binary_accuracy: 0.7423 - val_loss: 0.5445 - val_binary_accuracy: 0.7231
# Epoch 18/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.4848 - binary_accuracy: 0.7695 - val_loss: 0.5445 - val_binary_accuracy: 0.7298
# Epoch 19/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.4775 - binary_accuracy: 0.7760 - val_loss: 0.5728 - val_binary_accuracy: 0.7058
# Epoch 20/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.4540 - binary_accuracy: 0.7930 - val_loss: 0.5679 - val_binary_accuracy: 0.7221
# Epoch 21/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.4448 - binary_accuracy: 0.7969 - val_loss: 0.5631 - val_binary_accuracy: 0.7279
# Epoch 22/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.5042 - binary_accuracy: 0.7507 - val_loss: 0.6080 - val_binary_accuracy: 0.7144
# Epoch 23/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.4677 - binary_accuracy: 0.7767 - val_loss: 0.6059 - val_binary_accuracy: 0.6817
# Epoch 24/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.4307 - binary_accuracy: 0.8062 - val_loss: 0.5711 - val_binary_accuracy: 0.7327
# Epoch 25/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.4115 - binary_accuracy: 0.8151 - val_loss: 0.5999 - val_binary_accuracy: 0.7135
# Epoch 26/200
# 33/33 [==============================] - 0s 13ms/step - loss: 0.3738 - binary_accuracy: 0.8377 - val_loss: 0.6095 - val_binary_accuracy: 0.7038
# Epoch 27/200
# 33/33 [==============================] - 0s 13ms/step - loss: 0.3861 - binary_accuracy: 0.8269 - val_loss: 0.5914 - val_binary_accuracy: 0.7250
# Epoch 28/200
# 33/33 [==============================] - 0s 13ms/step - loss: 0.3640 - binary_accuracy: 0.8425 - val_loss: 0.6309 - val_binary_accuracy: 0.7029
# Epoch 29/200
# 33/33 [==============================] - 0s 13ms/step - loss: 0.3356 - binary_accuracy: 0.8582 - val_loss: 0.6470 - val_binary_accuracy: 0.7269
# Epoch 30/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.3028 - binary_accuracy: 0.8786 - val_loss: 0.6610 - val_binary_accuracy: 0.7173
# Epoch 31/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2730 - binary_accuracy: 0.8911 - val_loss: 0.7289 - val_binary_accuracy: 0.7163
# Epoch 32/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2692 - binary_accuracy: 0.8925 - val_loss: 0.7401 - val_binary_accuracy: 0.7183
# Epoch 33/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2430 - binary_accuracy: 0.9072 - val_loss: 0.7503 - val_binary_accuracy: 0.7144
# Epoch 34/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2311 - binary_accuracy: 0.9103 - val_loss: 0.8224 - val_binary_accuracy: 0.7288
# Epoch 35/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2195 - binary_accuracy: 0.9197 - val_loss: 0.8266 - val_binary_accuracy: 0.7231
# Epoch 36/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.2059 - binary_accuracy: 0.9269 - val_loss: 0.8329 - val_binary_accuracy: 0.7135
# Epoch 37/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1865 - binary_accuracy: 0.9305 - val_loss: 0.8707 - val_binary_accuracy: 0.7087
# Epoch 38/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1960 - binary_accuracy: 0.9221 - val_loss: 0.9905 - val_binary_accuracy: 0.7038
# Epoch 39/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1874 - binary_accuracy: 0.9286 - val_loss: 0.9559 - val_binary_accuracy: 0.7221
# Epoch 40/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1505 - binary_accuracy: 0.9433 - val_loss: 0.9486 - val_binary_accuracy: 0.6933
# Epoch 41/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1293 - binary_accuracy: 0.9572 - val_loss: 1.0708 - val_binary_accuracy: 0.7144
# Epoch 42/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1491 - binary_accuracy: 0.9459 - val_loss: 1.1234 - val_binary_accuracy: 0.7010
# Epoch 43/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.0921 - binary_accuracy: 0.9721 - val_loss: 1.1717 - val_binary_accuracy: 0.7135
# Epoch 44/200
# 33/33 [==============================] - 0s 12ms/step - loss: 0.1032 - binary_accuracy: 0.9647 - val_loss: 1.1483 - val_binary_accuracy: 0.7010

# %% [markdown]
# ### Evaluation

# %%
# Find the epoch with the highest validation accuracy
best_epoch = np.argmax(history['val_binary_accuracy'])

# Plot training and validation performance metrics
plt.figure(figsize=(20, 5))

# Plot training and validation loss
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=3)
plt.plot(history['val_loss'], label='Validation', alpha=0.8, color='#4D61E2', linewidth=3)
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=0.3)

plt.figure(figsize=(20, 5))

# Plot training and validation accuracy, highlighting the best epoch
plt.plot(history['binary_accuracy'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=3)
plt.plot(history['val_binary_accuracy'], label='Validation', alpha=0.8, color='#4D61E2', linewidth=3)
plt.plot(best_epoch, history['val_binary_accuracy'][best_epoch], marker='*', alpha=0.8, markersize=10, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=0.3)

plt.show()

# %%
# Calculate validation accuracy
val_pred = model.predict(X_val, verbose=0)
val_pred = (val_pred > 0.5).astype(int).flatten()  # convert to binary predictions 0/1
val_true = y_val
print('Validation accuracy: ', accuracy_score(val_true, val_pred))
# Out:
# Validation accuracy:  0.7326923076923076
