# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
from os import listdir, environ
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
print(tf.version)
print(tf.config.list_physical_devices('GPU'))
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\Nicolas\\anaconda3\\envs\\tensorflow\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>
# []

# %%
# For reproducible results
seed = 42
environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ### Data

# %%
# Constants
val_size = 0.2
data_path = 'public_data.npz'

# %%
# Read data
plants = np.load(data_path, allow_pickle=True)
X = plants['data']
y = plants['labels']

# Normalize image pixel values to a float range [0, 1]
X = (X / 255).astype(np.float32)

# Convert labels to categorical format using one-hot encoding
label_encoding = {'healthy': 0, 'unhealthy': 1}
y = np.array([label_encoding[label] for label in y])
y = tfk.utils.to_categorical(y, num_classes=2)

# Split into train and validation (hidden test set on codalab)
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=val_size, stratify=np.argmax(y,axis=1))

print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (4160, 96, 96, 3) (1040, 96, 96, 3) (4160, 2) (1040, 2)

# %% [markdown]
# ### ML

# %%
# Model parameters 
input_shape = X.shape[1:] 
output_shape = y.shape[1] 
batch_size = 64          
epochs = 200

# %%
# Build model using the LeNet-5 architecture
model = tfk.models.Sequential([
    tfkl.Input(shape=input_shape, name='input'),
    tfkl.Conv2D(filters=6, kernel_size=(5,5), padding='same', activation='tanh', name='conv1'),
    tfkl.MaxPooling2D(pool_size=(2,2), name='mp1'),
    tfkl.Conv2D(filters=16, kernel_size=(5,5), padding='valid', activation='tanh', name='conv2'),
    tfkl.MaxPooling2D(pool_size =(2,2), name='mp2'),
    tfkl.Flatten(name='flatten'),
    tfkl.Dense(units=120, activation='tanh', name='dense1'),
    tfkl.Dense(units=84,activation='tanh',name='dense2'),
    tfkl.Dense(units=output_shape, activation='softmax', name='Output')
])

# Compile the model
model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1 (Conv2D)              (None, 96, 96, 6)         456
#
#  mp1 (MaxPooling2D)          (None, 48, 48, 6)         0
#
#  conv2 (Conv2D)              (None, 44, 44, 16)        2416
#
#  mp2 (MaxPooling2D)          (None, 22, 22, 16)        0
#
#  flatten (Flatten)           (None, 7744)              0
#
#  dense1 (Dense)              (None, 120)               929400
#
#  dense2 (Dense)              (None, 84)                10164
#
#  Output (Dense)              (None, 2)                 170
#
# =================================================================
# Total params: 942,606
# Trainable params: 942,606
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define early stopping callback
early_stopping = tfk.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, mode='max', restore_best_weights=True)

# Train the model and save its history
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping]
).history

# Save the trained model
model.save('mark_I.h5')
# Out:
# Epoch 1/200
# 65/65 [==============================] - 7s 87ms/step - loss: 0.7904 - accuracy: 0.6103 - val_loss: 0.6469 - val_accuracy: 0.6327
# Epoch 2/200
# 65/65 [==============================] - 7s 101ms/step - loss: 0.6416 - accuracy: 0.6500 - val_loss: 0.6270 - val_accuracy: 0.6596
# Epoch 3/200
# 65/65 [==============================] - 7s 105ms/step - loss: 0.6114 - accuracy: 0.6714 - val_loss: 0.6077 - val_accuracy: 0.6721
# Epoch 4/200
# 65/65 [==============================] - 6s 96ms/step - loss: 0.5909 - accuracy: 0.6839 - val_loss: 0.6285 - val_accuracy: 0.6385
# Epoch 5/200
# 65/65 [==============================] - 9s 135ms/step - loss: 0.5505 - accuracy: 0.7135 - val_loss: 0.6177 - val_accuracy: 0.6635
# Epoch 6/200
# 65/65 [==============================] - 7s 106ms/step - loss: 0.5265 - accuracy: 0.7317 - val_loss: 0.6765 - val_accuracy: 0.6308
# Epoch 7/200
# 65/65 [==============================] - 7s 106ms/step - loss: 0.4669 - accuracy: 0.7776 - val_loss: 0.6801 - val_accuracy: 0.6433
# Epoch 8/200
# 65/65 [==============================] - 7s 105ms/step - loss: 0.4052 - accuracy: 0.8171 - val_loss: 0.7213 - val_accuracy: 0.6490
# Epoch 9/200
# 65/65 [==============================] - 7s 110ms/step - loss: 0.2984 - accuracy: 0.8767 - val_loss: 0.7959 - val_accuracy: 0.6567
# Epoch 10/200
# 65/65 [==============================] - 7s 106ms/step - loss: 0.2198 - accuracy: 0.9183 - val_loss: 0.8608 - val_accuracy: 0.6385
# Epoch 11/200
# 65/65 [==============================] - 8s 116ms/step - loss: 0.1398 - accuracy: 0.9541 - val_loss: 0.9849 - val_accuracy: 0.6615
# Epoch 12/200
# 65/65 [==============================] - 7s 108ms/step - loss: 0.0589 - accuracy: 0.9885 - val_loss: 1.1818 - val_accuracy: 0.6567
# Epoch 13/200
# 65/65 [==============================] - 9s 132ms/step - loss: 0.0252 - accuracy: 0.9971 - val_loss: 1.2748 - val_accuracy: 0.6558

# %% [markdown]
# ### Evaluation

# %%
# Find the epoch with the highest validation accuracy
best_epoch = np.argmax(history['val_accuracy'])

# Plot training and validation performance metrics
plt.figure(figsize=(20, 5))

# Plot training and validation loss
plt.plot(history['loss'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=3)
plt.plot(history['val_loss'], label='Validation', alpha=0.8, color='#4D61E2', linewidth=3)
plt.legend(loc='upper left')
plt.title('Binary Crossentropy')
plt.grid(alpha=0.3)

plt.figure(figsize=(20, 5))

# Plot training and validation accuracy, highlighting the best epoch
plt.plot(history['accuracy'], label='Training', alpha=0.8, color='#ff7f0e', linewidth=3)
plt.plot(history['val_accuracy'], label='Validation', alpha=0.8, color='#4D61E2', linewidth=3)
plt.plot(best_epoch, history['val_accuracy'][best_epoch], marker='*', alpha=0.8, markersize=10, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=0.3)

plt.show()

# %%
# Calculate validation accuracy
val_pred = model.predict(X_val, verbose=0)
val_pred = np.argmax(val_pred, axis=-1)
val_true = np.argmax(y_val, axis=-1)
print('Validation accuracy: ', accuracy_score(val_true, val_pred))
# Out:
# Validation accuracy:  0.6721153846153847
